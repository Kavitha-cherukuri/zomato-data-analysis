# %%
#add the column
import pandas as pd

data = {'Restaurant ID','Restaurant Name','Country Code','City','Address','Locality','Locality Verbose','Longitude','Latitude','Cuisines','Average Cost for two','Currency','Has Table booking','Has Online delivery','Is delivering now','Switch to order menu','Price range','Aggregate rating','Rating color','Rating text','Votes'}
#add column

df = pd.DataFrame(data)

#declare the column
col = {'Restaurant ID','Restaurant Name','Country Code','City','Address','Locality','Locality Verbose','Longitude','Latitude','Cuisines','Average Cost for two', 'Currency','Has Table booking','Has Online delivery','Is delivering now','Switch to order menu','Price range', 'Aggregate rating', 'Rating color', 'Rating text', 'Votes', 'rupee'}
df1 = pd.DataFrame(col)
df1 = pd.concat([df,df1],ignore_index = True)
# df2.reset_index()
display(df1)

# %%
#2 .Bring out a plot that compares indian currency with other country’s currency 

import plotly.graph_objects as go
import numpy as np

# Generating random data
np.random.seed(42)
data = np.random.normal(50, 10, 100)

# Creating the bar chart
fig = go.Figure(data=[go.Bar(x=data,
            marker=dict(color='yellow', line=dict(color='green',width=2)))])
fig.update_layout(title='zomato-csv', xaxis_title='country', yaxis_title='currency',bargap=0.01)
fig.show()

# %%
#Create a dropdown to choose the country-specific data 
# Any two charts of your choice(maybe count, total sales, favorite cuisines, etc) 


import plotly.graph_objects as go

zomato = go.india scatter(
         x = ['cuisine','latitude','currency','has table booking','votes']
        y  = ['cafe,fast food', 25.45343611, 'indian rupee', 'no', 76]  
    )
    [zomato]

# %%
#scatter plots
import plotly.graph_objects as go

zomato = go. india scatter(
         x = ['cuisine','latitude','currency','has table booking','votes']
        y  = [314, 591, 270, 1070, 1100]  
    )
    [zomato]

    layout = go.Layout(
    title='Scatter Plot',
    xaxis=dict(title='X-Axis'),
    yaxis=dict(title='Y-Axis')
)

fig = go.Figure(data=zomato, layout=layout)
fig.show()
# Out:
#   File "<ipython-input-5-064f541613b5>", line 4
#     zomato = go. india scatter(
#                        ^
# SyntaxError: invalid syntax

# %%
#Find which cuisines are costly in India 
#Filter based on the city 
import plotly.graph_objs as go

op_15_cuisines = zomatoDataPandas_withoutOutliers.cuisines.value_counts().head(15)

colors=['#57167E','#9B3192','#EA5F89','#F7B7A3','#FFF1C9','#E6F69D','#AADEA7','#64C2A6','#2D87BB','#3700FF']
fig=go.Figure(data=[go.Pie(labels=top_15_cuisines.index,values=top_15_cuisines.values,marker=dict(colors=colors))],layout=go.Layout(title='Top 10 Types of Cuisines'))
fig.show()


top_15_cuisines = top_15_cuisines.reset_index()
top_15_cuisines.index = np.arange(1, len(top_15_cuisines)+1)
top_15_cuisines.columns =['cuisines','count']
top_15_cuisines['count %'] = np.round(top_15_cuisines['count'] * 100 / sum(top_15_cuisines['count']),1).apply(lambda x:str(x) + "%")
top_15_cuisines
plt.show()

# %%
#Which is costlier cuisine 
#Rating count in the city (based on rating test) 
import plotly.graph_objs as go
import seaborn as sns

rating_t = zomato_df1.groupby(['address','rate'])
plt.figure(figsize=(6,5))
rating=rating_t.rate.nunique().index.to_frame()['rate'].dropna().apply(lambda x : float(x.split('/')[0]) if (len(x)>3)  else np.nan ).dropna()
sns.distplot(rating,bins=20,kde_kws={"color": "k", "lw": 3, "label": "KDE"})
plt.show()

# %%
#Pie chart online delivery vs dine-in 
import plotly.graph_objs as go

zomato = zomato.csvPandas_withoutOutliers.zomato.csv.value_counts().head(10)
colors=['#57167E','#9B3192','#EA5F89','#F7B7A3','#FFF1C9','#E6F69D','#AADEA7','#64C2A6','#2D87BB','#3700FF']
fig=go.Figure(data=[go.Pie(labels='delivary'.index,values='dine-in'.values,marker=dict(colors=colors))],layout=go.Layout(title='zomato.csv'))
fig.show()
plt.show()

# %%
#Which part of India spends more on online deliver

import plotly.graph_objs as go

zomatoDataPyspark.crosstab('approxCost(2 people)','onlineOrder').orderBy(['Yes','No'],ascending=[False,True]).show()

# %%
#Which part of India spends more on dine-in 
import plotly.graph_objs as go
allCuisines = set()

for i in zomatoDataPandas_withoutOutliers.cuisines:
    for j in i.split(', '):
        allCuisines.add(j)    
        
print("There are total {0} Cuisines that are available in bangalore".format(len(allCuisines)))

# %%
#Which part has a high living cost vs low living cost
import plotly.graph_objs as go

zomato = zomato.csvPandas_withoutOutliers.zomato.csv.value_counts().head(10)
colors=['#57167E','#9B3192','#EA5F89','#F7B7A3','#FFF1C9','#E6F69D','#AADEA7','#64C2A6','#2D87BB','#3700FF']
fig=go.Figure(data=[go.Pie(labels='high living cost'.index,values='low living cos'.values,marker=dict(colors=colors))],layout=go.Layout(title='zomato.csv'))
fig.show()
plt.show()

# %% [markdown]
# # New Section
